# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob
import PIL

# %%
filelist = glob.glob('./imgs/output*.jpg')
# print(filelist)

imagenes = []
for file in filelist:
    imagenes.append(plt.imread(file))

# %%
# %matplotlib inline
plt.imshow(imagenes[76]);

# %%
u = imagenes[76]
v = cv2.Canny(u, 240, 380);

plt.imshow(u, cmap='gray');

# %% [markdown]
# conclusión: Canny no sé si sirve

# %%
u = imagenes[76]
print(u.shape)
v = np.reshape(u[:,:,0],(-1))
print(v.shape)
# Out:
# (256, 256, 3)
# (65536,)
# [[[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  ...,
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...,
#   [False False False]
#   [False False False]
#   [False False False]]]

# %%
w = (u > 0)
#print(w)

plt.imshow(np.floor(w*255).astype(np.uint8))

# %% [markdown]
# Muchos puntos aparecen medio sueltos y desconectados.
# Por ahí antes de identificar las diferentes islas es más útil difuminar (blur) la imágen.

# %%
# TODO: Hacer blur sobre la imagen para que queden manchas conexas

# %% [markdown]
# Ahora si se puede correr el identificador "label" sobre las manchas:
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.label.html
#
# ndimage.label busca las manchas simplemente conexas dentro de la imagen y las enumera

# %%
def contar_manchas(img):
    
    # TODO: correr el identificador label sobre la imagen para identificar
    # las diferentes manchas conexas.

    
    return listado_de_manchas

# %% [markdown]
# Corremos `contar_manchas()` sobre todas las imagenes...

# %%
for imagen in imagenes:
    print(contar_manchas(imagen))
