# %% [markdown]
# # TP 1
# wazu wazol

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_r = plt.imread('im0.png')
img_l = plt.imread('im1.png')

print(img_r.shape)

# %matplotlib inline
# a = img_r[0:1000,0:500,:]

r = img_r[:,:, 0]
g = img_r[:,:, 1]
b = img_r[:,:, 2]

print(r.shape)


i = (r+g+b)/3

a = cv2.resize(i, (200,296))

plt.hist(np.reshape(a,(-1,1)))
#img_r_normalizada = 

plt.figure('recortado');
plt.imshow(a, cmap='gray');
# Out:
# (2000, 2964, 3)
# (2000, 2964)
# [[ 0.34263596  0.34107563  0.26363805 ...,  0.1058064   0.22309203
#    0.08800513]
#  [ 0.3294169   0.35126638  0.27123302 ...,  0.05430313  0.21538422
#    0.06695972]
#  [ 0.32762092  0.35787231  0.24276629 ...,  0.04678149  0.09194453
#    0.04603427]
#  ...,
#  [ 0.47915265  0.52675772  0.49488077 ...,  0.59130895  0.58349055
#    0.58240348]
#  [ 0.53650278  0.55126977  0.4952791  ...,  0.57309049  0.57663822
#    0.57755965]
#  [ 0.47897598  0.53521442  0.46529943 ...,  0.54597682  0.57789385
#    0.57198948]]

# %%
u = np.floor(img_r*255).astype(np.uint8)

u = cv2.resize(u, (296,200))

v = cv2.Canny(u, 250, 950)

plt.imshow(v)

# %%
x =
